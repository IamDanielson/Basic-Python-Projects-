# %%
import pandas as pd

# %%
excel1 =('lagos.xlsx')

# %%
excel2 = ('ph.xlsx')

# %%
df1 = pd.read_excel(excel1)

# %%
df2 = pd.read_excel(excel2)

# %%
value1 = df1[['Locations','No_of_Banks','No_supermarts']]

# %%
value2 = df2[['Locations','No_of_Banks','No_supermarts']]

# %%
dataframe = [value1,value2]

# %%
join = pd.concat(dataframe)

# %%
join.to_excel('output.xlsx')

# %%
df1
# Out:
#     Locationid      Locations  No_of_Banks  Hotel  No_supermarts  \
# 0          101          Lekki            9      8             11
# 1          102           Ajax           12      7              8
# 2          103          Ikoyi            8      6              9
# 3          104  Banana_island            8      8             11
# 4          105          Ikeja           11      5              8
# 5          106          Lekki           12      7             11
# 6          107           Ajax            8      6             12
# 7          108          Ikoyi           12      5              8
# 8          109  Banana_island           10      6             12
# 9          110          Ikeja           10      8             12
# 10         111          Lekki            8      5             11
# 11         112           Ajax           11      5              9
# 12         113          Ikoyi           10      5              8
# ...

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.barplot(x='Sex', y='Survived' ,data=titanic)

# %%
sns.barplot(x='Sex', y='Pclass' ,data=titanic, hue='Pclass')

# %%
sns.categorical('Embarked',data=titanic, hue='Survived')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-b8a85a07c4c7> in <module>
# ----> 1 sns.categorical('Embarked',data=titanic, hue='Survived')
#
# TypeError: 'module' object is not callable

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
