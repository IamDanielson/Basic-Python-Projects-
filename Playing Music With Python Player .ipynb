# %%
# !pip install librosa
# audio processing package - librosa
import librosa
import librosa.display
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
A,sr = librosa.load(r"C:/Users/Danielson/Desktop/tone_220.wav")
print(type(A))
print(type(sr))
# Out:
# <class 'numpy.ndarray'>
# <class 'int'>

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(A, sr=sr)
