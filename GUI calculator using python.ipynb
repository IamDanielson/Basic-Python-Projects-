# %%
import tkinter
from tkinter import *
def calculate():
    Patientid = entry.get()
    Age = entry1.get()
    Glucose = int(entry2.get())
    Blood_pressure = int(entry3.get())
    insulin = int(entry4.get())
    if int(entry2.get()) > 125 and int(entry3.get()) > 95 and int(entry4.get())> 225:
        slabel = tkinter.Label(root, text="Positive")
        slabel.grid()
    else:
        tlabel = tkinter.Label(root, text="Negative")
        tlabel.grid() 
    output_label.configure(text='Submit: {:.1f}'.format(D))
    entry.delete(0,END)
    entry1.delete(0,END)
    entry2.delete(0,END)
    entry3.delete(0,END)
    entry4.delete(0,END)
root = Tk()
root.title("DECISION BASED SUPPORT SYSTEM",font="Helvetica 18 bold")
root.iconbitmap('C:/Users/Danielson/Desktop/globe_earth_internet_icon_153738.ico')
root.configure(bg="orange")
message_label = Label(text= "Productid:",font=('Georgia',16),fg="green",bg='orange',height="3")
message_label1 = Label(text= "Age",font=('Georgia',16),fg="red",bg='orange',height="3")
message_label2 = Label(text= "Glucose",font=('Georgia',16),bg='orange',height="3", width = "7")
message_label3 = Label(text= "Blood Pressure",font=('Georgia',16),bg='orange',height="3")
message_label4 = Label(text= "Insulin",font=('Georgia',16),fg="blue",bg='orange',height="3", width="7")
output_label = Label(font=('Georgia',16),bg='orange')
output_label1 = Label(font=('Georgia',16),bg='orange')
output_label2 = Label(font=('Georgia',16))
output_label3 = Label(font=('Georgia',16))
output_label4 = Label(font=('Georgia',16))
entry = Entry(font=('Georgia', 16), width=20)
entry1 = Entry(font=('Georgia', 16), width=20)
entry2 = Entry(font=('Georgia', 16), width=20)
entry3 = Entry(font=('Georgia', 16), width=20)
entry4 = Entry(font=('Georgia', 16), width=20)
calc_button = Button(text='Summit', font=('Georgia', 16),command=calculate)
message_label.grid(row=0, column=0)
message_label1.grid(row=2, column=0)
message_label2.grid(row=2, column=2)
message_label3.grid(row=6, column=0)
message_label4.grid(row=6, column=2)
entry.grid(row=0, column=1)
entry1.grid(row=2, column=1)
entry2.grid(row=2, column=3)
entry3.grid(row=6, column=1)
entry4.grid(row=6, column= 3)
calc_button.grid(row=8 , column=2)
output_label.grid(row=7, column=0, columnspan=3)
mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-98f114783cb6> in <module>
#      20     entry4.delete(0,END)
#      21 root = Tk()
# ---> 22 root.title("DECISION BASED SUPPORT SYSTEM",font="Helvetica 18 bold")
#      23 root.iconbitmap('C:/Users/Danielson/Desktop/globe_earth_internet_icon_153738.ico')
#      24 root.configure(bg="orange")
#
# TypeError: wm_title() got an unexpected keyword argument 'font'

# %%
import tkinter as tk 
from PIL import ImageTk, Image

Height = 500
Width = 1000

def convert():
    Patientid = entry.get()
    Age = entry2.get()
    Glucose = int(entry3.get())
    Blood_pressure = int(entry4.get())
    insulin = int(entry5.get())
   
    if int(entry3.get()) > 125 and int(entry4.get()) > 95 and int(entry5.get())> 225:
        slabel = tk.Label(frame, text="Positive", font = ('Georgia', 20),bg = '#F4FA58', bd = 5)
        slabel.pack()
    else:
        tlabel = tk.Label(frame, text="Status: Negative", font=('Georgia', 20), bg = '#F4FA58', bd = 5)
        tlabel.pack() 
        
def grab(y):
    opt = variable.get()
    chosen =tk.Label(text=opt)

        
root = tk.Tk()
root.title("DECISION BASED SUPPORT SYSTEM")
canvas = tk.Canvas(root, height = Height, width = Width)
canvas.pack()


background_image = ImageTk.PhotoImage(Image.open("ms.gif"))
background_label = tk.Label(root, image = background_image)
background_label.place(relwidth=1.2, relheight=1.2)

variable = tk.string(root)
variable.set('select Gender: ')
entry = tk.OptionMenu(root, variable, "Male", "Female", command =grab)


entry1 = tk.Entry(font=('Georgia', 16))
entry2 = tk.Entry(font=('Georgia', 16))
entry3 = tk.Entry(font=('Georgia', 16))
entry4 = tk.Entry(font=('Georgia', 16))
entry5 = tk.Entry(font=('Georgia', 16))
entry.place(relx=0.3, rely=0.2,relwidth=0.1, relheight = 0.05)
entry1.place(relx=0.3, rely=0.3,relwidth=0.1, relheight = 0.05)
entry2.place(relx=0.3,rely=0.4,relwidth=0.1, relheight = 0.05)
entry3.place(relx=0.3, rely=0.5,relwidth=0.1, relheight = 0.05)
entry4.place(relx=0.3, rely=0.6, relwidth=0.1, relheight = 0.05)

button = tk.Button(root, text='Submit', font = ('Georgia', 16), command=convert)
button.pack(side = 'right')


message_label = tk.Label(text= "Product_ID:",font=('Georgia',13))
message_label.place(relx=0, rely=0.2, relheight=0.1, relwidth=0.3)

message_label1 = tk.Label(text= "Age",font=('Georgia',13))
message_label1.place(relx=0, rely=0.3, relheight=0.1, relwidth=0.3)

message_label2 = tk.Label(text= "Glucose",font=('Georgia',13))
message_label2.place(relx=0, rely=0.4, relheight=0.1, relwidth=0.3)

message_label3 = tk.Label(text= "Blood Pressure",font=('Georgia',13))
message_label3.place(relx=0, rely=0.5, relheight=0.1, relwidth=0.3)

message_label4 = tk.Label(text= "Insulin",font=('Georgia',13))
message_label4.place(relx=0, rely=0.6, relheight=0.1, relwidth=0.3)

img = ImageTk.PhotoImage(file='c72b10c2-f0ed-4c7a-a054-06a91a29a3aa_200x200.bmp')

label = tk.Label(root,text = 'DECISION BASED SUPPORT SYSTEM',font=('Georgia',30, 'bold'),bg='#F4FA58',image=img,compound ='right')
label.place(relx = 0, rely = 0, relwidth = 1, relheight = 0.2)

button_exit = tk.Button(root,text ="Exit Program", command = quit)
button_exit.pack()
                          
root.mainloop()
