# %%
import pandas as pds
import numpy as npy

# %%
spar = pds.read_csv('customerdata.csv',index_col='customerID')

# %%
spar
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
# ...

# %%
spar.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
spar.size
# Out:
# 140860

# %%
spar.shape
# Out:
# (7043, 20)

# %%
spar.ndim
# Out:
# 2

# %%
spar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
spar.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
spar[['gender','SeniorCitizen', 'Contract', 'MonthlyCharges','TotalCharges']]
# Out:
#             gender  SeniorCitizen        Contract  MonthlyCharges TotalCharges
# customerID
# 7590-VHVEG  Female              0  Month-to-month           29.85        29.85
# 5575-GNVDE    Male              0        One year           56.95       1889.5
# 3668-QPYBK    Male              0  Month-to-month           53.85       108.15
# 7795-CFOCW    Male              0        One year           42.30      1840.75
# 9237-HQITU  Female              0  Month-to-month           70.70       151.65
# ...            ...            ...             ...             ...          ...
# 6840-RESVB    Male              0        One year           84.80       1990.5
# 2234-XADUH  Female              0        One year          103.20       7362.9
# 4801-JZAZL  Female              0  Month-to-month           29.60       346.45
# 8361-LTMKD    Male              1  Month-to-month           74.40        306.6
# 3186-AJIEK    Male              0        Two year          105.65       6844.5
#
# ...

# %%
female = spar[spar.gender == 'Female']

# %%
female
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 6713-OKOMC  Female              0      No         No      10           No
# 7892-POOKP  Female              0     Yes         No      28          Yes
# ...            ...            ...     ...        ...     ...          ...
# 0639-TSIQW  Female              0      No         No      67          Yes
# 7750-EYXWZ  Female              0      No         No      12           No
# 2569-WGERO  Female              0      No         No      72          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
#
# ...

# %%
Male = spar[spar.gender == 'Male']

# %%
Male
# Out:
#            gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 5575-GNVDE   Male              0      No         No      34          Yes
# 3668-QPYBK   Male              0      No         No       2          Yes
# 7795-CFOCW   Male              0      No         No      45           No
# 1452-KIOVK   Male              0      No        Yes      22          Yes
# 6388-TABGU   Male              0      No        Yes      62          Yes
# ...           ...            ...     ...        ...     ...          ...
# 9767-FFLEM   Male              0      No         No      38          Yes
# 8456-QDAVC   Male              0      No         No      19          Yes
# 6840-RESVB   Male              0     Yes        Yes      24          Yes
# 8361-LTMKD   Male              1     Yes         No       4          Yes
# 3186-AJIEK   Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
Male[Male.tenure>=60]
# Out:
#            gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 6388-TABGU   Male              0      No        Yes      62          Yes
# 9959-WOFKT   Male              0      No        Yes      71          Yes
# 5248-YGIJN   Male              0     Yes         No      72          Yes
# 5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 1215-FIGMP   Male              0      No         No      60          Yes
# ...           ...            ...     ...        ...     ...          ...
# 2451-YMUXS   Male              1      No         No      67          Yes
# 0218-QNVAS   Male              0     Yes        Yes      71          Yes
# 2274-XUATA   Male              1     Yes         No      72           No
# 7203-OYKCT   Male              0      No         No      72          Yes
# 3186-AJIEK   Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
Male[Male.MonthlyCharges>=100]
# Out:
#            gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 8091-TTVAX   Male              0     Yes         No      58          Yes
# 0280-XJGEX   Male              0      No         No      49          Yes
# 5129-JLPIS   Male              0      No         No      25          Yes
# 9959-WOFKT   Male              0      No        Yes      71          Yes
# 5380-WJKOV   Male              0      No         No      34          Yes
# ...           ...            ...     ...        ...     ...          ...
# 9547-ITEFG   Male              0     Yes        Yes       9          Yes
# 0218-QNVAS   Male              0     Yes        Yes      71          Yes
# 0093-XWZFY   Male              0      No         No      40          Yes
# 7203-OYKCT   Male              0      No         No      72          Yes
# 3186-AJIEK   Male              0      No         No      66          Yes
#
#            MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
spar.groupby('gender').size()
# Out:
# gender
# Female    3488
# Male      3555
# dtype: int64

# %%
spar.groupby('gender').sum()
# Out:
#         SeniorCitizen  tenure  MonthlyCharges
# gender
# Female            568  112469        227432.4
# Male              574  115521        228684.2

# %%
spar.size
# Out:
# 140860

# %%
spar[['SeniorCitizen']].size
# Out:
# 7043

# %%
spar[['SeniorCitizen']].sum
# Out:
# <bound method DataFrame.sum of             SeniorCitizen
# customerID
# 7590-VHVEG              0
# 5575-GNVDE              0
# 3668-QPYBK              0
# 7795-CFOCW              0
# 9237-HQITU              0
# ...                   ...
# 6840-RESVB              0
# 2234-XADUH              0
# 4801-JZAZL              0
# 8361-LTMKD              1
# 3186-AJIEK              0
#
# [7043 rows x 1 columns]>

# %%
spar[['tenure']].sum
# Out:
# <bound method DataFrame.sum of             tenure
# customerID
# 7590-VHVEG       1
# 5575-GNVDE      34
# 3668-QPYBK       2
# 7795-CFOCW      45
# 9237-HQITU       2
# ...            ...
# 6840-RESVB      24
# 2234-XADUH      72
# 4801-JZAZL      11
# 8361-LTMKD       4
# 3186-AJIEK      66
#
# [7043 rows x 1 columns]>

# %%
spar[['Contract']].sum
# Out:
# <bound method DataFrame.sum of                   Contract
# customerID
# 7590-VHVEG  Month-to-month
# 5575-GNVDE        One year
# 3668-QPYBK  Month-to-month
# 7795-CFOCW        One year
# 9237-HQITU  Month-to-month
# ...                    ...
# 6840-RESVB        One year
# 2234-XADUH        One year
# 4801-JZAZL  Month-to-month
# 8361-LTMKD  Month-to-month
# 3186-AJIEK        Two year
#
# [7043 rows x 1 columns]>

# %%
spar.groupby('gender').size()
# Out:
# gender
# Female    3488
# Male      3555
# dtype: int64

# %%
spar.groupby('gender').sum()
# Out:
#         SeniorCitizen  tenure  MonthlyCharges
# gender
# Female            568  112469        227432.4
# Male              574  115521        228684.2
